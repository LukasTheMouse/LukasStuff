# %%
import libraries /random/ click

define dict (with boats abbriviatios / real names)

define dict (with boats/ hit points)


def create_field(input(x)):

    create list in list from x by x 

    return field


def place_boats_CPU(field,dictboats)
    
    for boats in dictboats:    

    x = randint(0,len(sizefield) )   
    y = randint(0,len(sizefield) - sizeboat )   
    
    for i in range(sizefield) 
        field[location_x][location_y] = key.signboat
        
    ### optional make it possible that boats can turn 
    
    ### avoid copying over eachother
    
    ### 

    return field


def place_boats_player(field,dictboats):
    
    for boats in dictboats: 
    
    x = input(provide number between 0 and 9)
    
    y = input(provide number between 0 and 9)
    
    while True 
        -  x and y are numbers between 0 and 9
        -  x and y are int

        for i in range(sizefield) 
        field[location_x][location_y] = key.signb
    
    return field


def Shooting(field,player):

    if Player = "CPU"
    
        x, y = randint(0,size(field))
    
    field[x][y] == 'HIT'
    
    return field
        
    else Plyser 
    
        x = input(provide number between 0 and 9)
    
        y = input(provide number between 0 and 9)

        while True 
            -  x and y are numbers between 0 and 9
            -  x and y are int

        field[x][y] == 'HIT'

    return field


def turn_player/CPU(player): #One /maybe two separate functions
    
    gives feedback on the results of the shooting and counts down on the hitpoints that are lost
    
    - You missed 
    
    - You hit 
    
    - You hit the same spot
    
    ##Optional make notice on the moment a boat sank
    
    
    
def main()

    field_player, Field_cpu = create_field(x)
    
    field_player = place_boats_player(field_player)
    
    Field_cpu =  place_boats_CPU(Field_cpu)
    
    starting hitpoints for cpu/plare = count(hitpoints in list in list):
        
    while one of the hitpoints > 0 = True
        
        
        hitpoint_CPU = turn_player(CPU) 
        
        hitpoint_player = turn_player(player) 

        if hitpoint_CPU == 0:
            player won
            
        elif hitpoint_CPU == 0:
            player won
            
            
            
def create_menu()
    
    while players wants to continue
    
    play_game/main
    
    if players wants to stops. press code for exit game
    
    # Break on moment game is over for MVP
    
    # ask player for another game if games is over
    
    
#Ideas   
    # ideas CPU learns from mistakes / hits
    # boats are object / create classes for different objects in the games.
